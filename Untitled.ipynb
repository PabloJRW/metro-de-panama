# %%
import numpy as np
import pandas as pd
import datetime as dt

# %%
! ls ingresos_tarifarios
# Out:
#  ingresos-tarifarios-mpsa-2018.csv
#  ingresos-tarifarios-mpsa-2019.csv
#  ingresos-tarifarios-mpsa-2021.csv
# 'ingresos-tarifarios-mpsa-diciembre-2020(1).csv'
#  ingresos-tarifarios-mpsa-diciembre-2020.csv

# %%
ing_tar_2018 = pd.read_csv('ingresos_tarifarios/ingresos-tarifarios-mpsa-2018.csv', delimiter=';')
ing_tar_2018
# Out:
#                    METRO DE PANAMA        Unnamed: 1       Unnamed: 2  \
# 0   RESUMEN DE INGRESOS TARIFARIOS               NaN              NaN
# 1            PRIMER TRIMESTRE 2018               NaN              NaN
# 2                              MES  Ingreso Monedero              NaN
# 3                              NaN         Pasajeros       Monto Real
# 4                            ENERO         6,461,578     2,261,552.30
# 5                          FEBRERO         5,788,565     2,025,997.75
# 6                            MARZO         7,110,591     2,488,706.85
# 7                    INGRESO TOTAL        19,360,734  B/.6,776,256.90
# 8                              NaN               NaN              NaN
# 9                  METRO DE PANAMA               NaN              NaN
# 10  RESUMEN DE INGRESOS TARIFARIOS               NaN              NaN
# 11          SEGUNDO TRIMESTRE 2018               NaN              NaN
# ...
